# %%
# =============================================================================
# 1. IMPORT LIBRARIES
# =============================================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Display Settings (for cleaner visuals)
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %%
# =============================================================================
# 2. ENTER CSV FILE PATH
# =============================================================================

csv_path = input("Please enter the full path to your CSV file: ")

# Clean the path
csv_path = csv_path.strip().replace('"', "").replace("'", "")

print("\nPath you entered:")
print(csv_path)
# Out:
# Please enter the full path to your CSV file:  C:\0_DA\Iot_DataAnalyst\smart_grid_dataset_city_hourly_enriched.csv
# Path you entered:
# C:\0_DA\Iot_DataAnalyst\smart_grid_dataset_city_hourly_enriched.csv

# %%
# =============================================================================
# 2. ENTER CSV FILE PATH
# =============================================================================

csv_path = input("Please enter the full path to your CSV file: ")

# Clean the path
csv_path = csv_path.strip().replace('"', "").replace("'", "")

print("\nPath you entered:")
print(csv_path)
# Out:
# Please enter the full path to your CSV file:  C:\0_DA\Iot_DataAnalyst\smart_grid_dataset_city_hourly_enriched.csv
# Path you entered:
# C:\0_DA\Iot_DataAnalyst\smart_grid_dataset_city_hourly_enriched.csv

# %%
# =============================================================================
# 3. READ CSV FILE AND DISPLAY BASIC INFORMATION
# =============================================================================

df = pd.read_csv(csv_path)

print("=" * 80)
print("CSV file loaded successfully!")
print("=" * 80)

# Show number of rows and columns
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")

# Display the first 5 rows
print("\nFirst 5 rows of the dataset:")
display(df.head())

# Show column names
print("\nColumn names:")
print(df.columns.tolist())
# Out:
# ...
# CSV file loaded successfully!
# ...
# Number of rows: 50000
# Number of columns: 27
#
# First 5 rows of the dataset:
#              Timestamp    City               Name    Country region  \
# 0  2024-01-01 03:00:00  Astana  Astana_PowerPlant  SolarPark   Asia
# 1  2024-01-01 07:00:00  Astana  Astana_PowerPlant  SolarPark   Asia
# 2  2024-01-01 11:00:00  Astana  Astana_PowerPlant  SolarPark   Asia
# 3  2024-01-01 15:00:00  Astana  Astana_PowerPlant  SolarPark   Asia
# 4  2024-01-01 19:00:00  Astana  Astana_PowerPlant  SolarPark   Asia
#
#    Voltage (V)  Current (A)  Power Consumption (kW)  Reactive Power (kVAR)  \
# 0   220.433599    32.759661                7.221330               1.162562
# 1   228.541531    24.829354                5.674539               2.262425
# 2   226.400779    43.082521                9.753916               1.284079
# 3   229.071705    21.943347                5.026600               0.941152
# ...
